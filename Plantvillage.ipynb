# %%
import os
import pandas as pd 
import numpy as np

# %%
# path='D:\Tomato leaf detection\plantvillage'/
path=os.getcwd()+'\\plantvillage'

# %%
os.getcwd()
# Out:
# 'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage'

# %%
root_dir=os.listdir(os.getcwd()+'\\plantvillage')

# %%
print(root_dir)
# Out:
# ['Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___healthy', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_mosaic_virus', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus']

# %%
classes=[]
for directory in root_dir:
    if 'Tomato' in directory:
        #print(directory)
        classes.append(directory.replace('Tomato___',''))
print(classes)
# Out:
# ['Bacterial_spot', 'Early_blight', 'healthy', 'Late_blight', 'Leaf_Mold', 'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite', 'Target_Spot', 'Tomato_mosaic_virus', 'Tomato_Yellow_Leaf_Curl_Virus']

# %%
len(classes)
# Out:
# 10

# %%
temp=[]
meta=[]
for directory in root_dir:
    if 'Tomato' in directory:
        image_list=os.listdir(f'{path}/{directory}')
        for image_name in image_list:
            temp=[]
            temp.append(image_name)
            temp.append(directory.replace('Tomato___',''))
            meta.append(temp)

# %%
meta
# Out:
# [['00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG',
#   'Bacterial_spot'],
#  ['0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_Bact.Sp 6254.JPG',
#   'Bacterial_spot'],
#  ['00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_BS_Lab Leaf 1054.JPG',
#   'Bacterial_spot'],
#  ['00a7c269-3476-4d25-b744-44d6353cd921___GCREC_Bact.Sp 5807.JPG',
#   'Bacterial_spot'],
#  ['00b7e89a-e129-4576-b51f-48923888bff9___GCREC_Bact.Sp 6202.JPG',
#   'Bacterial_spot'],
#  ['01375198-62af-4c40-bddf-f3c11107200b___GCREC_Bact.Sp 5914.JPG',
#   'Bacterial_spot'],
#  ['014b58ae-091b-408a-ab4a-5a780cd1c3f3___GCREC_Bact.Sp 2971.JPG',
#   'Bacterial_spot'],
#  ['01a3cf3f-94c1-44d5-8972-8c509d62558e___GCREC_Bact.Sp 3396.JPG',
#   'Bacterial_spot'],
#  ['01a46cb5-d354-4f59-868e-e56186701541___GCREC_Bact.Sp 5638.JPG',
#   'Bacterial_spot'],
#  ['01d7f4fe-793f-4a9b-bc8b-8aa05200984f___GCREC_Bact.Sp 2984.JPG',
#   'Bacterial_spot'],
#  ['01e079ba-939a-4681-8983-db663f4a859b___GCREC_Bact.Sp 3029.JPG',
# ...

# %%
array=np.asarray(meta)
df=pd.DataFrame(array)

# %%
df.rename(columns={0:'image_name',1:'type_of_disease'},inplace=True)

# %%
df.head()
# Out:
#                                           image_name type_of_disease
# 0  00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_B...  Bacterial_spot
# 1  0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_B...  Bacterial_spot
# 2  00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_...  Bacterial_spot
# 3  00a7c269-3476-4d25-b744-44d6353cd921___GCREC_B...  Bacterial_spot
# 4  00b7e89a-e129-4576-b51f-48923888bff9___GCREC_B...  Bacterial_spot

# %%
df.to_csv('meta.csv')

# %%
images=os.listdir(f'{path}/Tomato___Bacterial_spot')

# %%
len(images)
# Out:
# 1702

# %%
df.head()
# Out:
#                                           image_name type_of_disease
# 0  00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_B...  Bacterial_spot
# 1  0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_B...  Bacterial_spot
# 2  00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_...  Bacterial_spot
# 3  00a7c269-3476-4d25-b744-44d6353cd921___GCREC_B...  Bacterial_spot
# 4  00b7e89a-e129-4576-b51f-48923888bff9___GCREC_B...  Bacterial_spot

# %%
df.count()
# Out:
# image_name         14529
# type_of_disease    14529
# dtype: int64

# %%
image_paths=[]

# %%
for directory in root_dir:
    if 'Tomato' in directory:
        image_list=os.listdir(f'{path}/{directory}')
        for image_name in image_list:
            image_paths.append(path+'\\'+directory+'\\'+image_name)

# %%
image_paths
# Out:
# ['C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG',
#  'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_Bact.Sp 6254.JPG',
#  'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_BS_Lab Leaf 1054.JPG',
#  'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\00a7c269-3476-4d25-b744-44d6353cd921___GCREC_Bact.Sp 5807.JPG',
#  'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\00b7e89a-e129-4576-b51f-48923888bff9___GCREC_Bact.Sp 6202.JPG',
# ...

# %%
import cv2

# %%
df['Image_Path']=image_paths

# %%
df.head()
# Out:
#                                           image_name type_of_disease
# 0  00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_B...  Bacterial_spot
# 1  0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_B...  Bacterial_spot
# 2  00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_...  Bacterial_spot
# 3  00a7c269-3476-4d25-b744-44d6353cd921___GCREC_B...  Bacterial_spot
# 4  00b7e89a-e129-4576-b51f-48923888bff9___GCREC_B...  Bacterial_spot

# %%
df.iloc[0][2]
# Out:
# 'C:\\Users\\waseem hasan\\plantvillage tomato\\plantvillage\\plantvillage\\Tomato___Bacterial_spot\\00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'

# %%
df.iloc[0][0]
# Out:
# '00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_Bact.Sp 3110.JPG'

# %%
df.to_csv('meta.csv')

# %%
df.describe()
# Out:
#                                                image_name  \
# count                                               14529
# unique                                              14529
# top     c9f92d4b-9d9c-4932-ba1b-bc290987c154___RS_HL 0...
# freq                                                    1
#
#                       type_of_disease  \
# count                           14529
# unique                             10
# top     Tomato_Yellow_Leaf_Curl_Virus
# freq                             4286
#
#                                                Image_Path
# count                                               14529
# unique                                              14529
# top     C:\Users\waseem hasan\plantvillage tomato\plan...
# freq                                                    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14529 entries, 0 to 14528
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   image_name       14529 non-null  object
#  1   type_of_disease  14529 non-null  object
#  2   Image_Path       14529 non-null  object
# dtypes: object(3)
# memory usage: 340.6+ KB

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14524    False
# 14525    False
# 14526    False
# 14527    False
# 14528    False
# Length: 14529, dtype: bool

# %%
df.isnull().sum()
# Out:
# image_name         0
# type_of_disease    0
# Image_Path         0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(221)
df['type_of_disease'].value_counts().plot(kind='bar', ax=ax1)
ax1.set_ylabel('Count')
ax1.set_title('Cell Type');

# %%
df['type_of_disease'].value_counts()
# Out:
# Tomato_Yellow_Leaf_Curl_Virus           4286
# Bacterial_spot                          1702
# Late_blight                             1527
# Septoria_leaf_spot                      1417
# Spider_mites Two-spotted_spider_mite    1341
# healthy                                 1273
# Target_Spot                             1123
# Early_blight                             800
# Leaf_Mold                                761
# Tomato_mosaic_virus                      299
# Name: type_of_disease, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(df['type_of_disease'])
LabelEncoder()
le.classes_
# Out:
# array(['Bacterial_spot', 'Early_blight', 'Late_blight', 'Leaf_Mold',
#        'Septoria_leaf_spot', 'Spider_mites Two-spotted_spider_mite',
#        'Target_Spot', 'Tomato_Yellow_Leaf_Curl_Virus',
#        'Tomato_mosaic_virus', 'healthy'], dtype=object)

# %%
df['label']=le.transform(df['type_of_disease'])

# %%
df.head()
# Out:
#                                           image_name type_of_disease  \
# 0  00416648-be6e-4bd4-bc8d-82f43f8a7240___GCREC_B...  Bacterial_spot
# 1  0045ba29-ed1b-43b4-afde-719cc7adefdb___GCREC_B...  Bacterial_spot
# 2  00639d29-2d1a-4fcf-9bd3-a2b3109c74c4___UF.GRC_...  Bacterial_spot
# 3  00a7c269-3476-4d25-b744-44d6353cd921___GCREC_B...  Bacterial_spot
# 4  00b7e89a-e129-4576-b51f-48923888bff9___GCREC_B...  Bacterial_spot
#
#                                           Image_Path  label
# 0  C:\Users\waseem hasan\plantvillage tomato\plan...      0
# 1  C:\Users\waseem hasan\plantvillage tomato\plan...      0
# 2  C:\Users\waseem hasan\plantvillage tomato\plan...      0
# 3  C:\Users\waseem hasan\plantvillage tomato\plan...      0
# 4  C:\Users\waseem hasan\plantvillage tomato\plan...      0

# %%
from sklearn.utils import resample

# %%
df_0 = df[df['label'] == 0]
df_1 = df[df['label'] == 1]
df_2 = df[df['label'] == 2]
df_3 = df[df['label'] == 3]
df_4 = df[df['label'] == 4]
df_5 = df[df['label'] == 5]
df_6 = df[df['label'] == 6]
df_7 = df[df['label'] == 7]
df_8 = df[df['label'] == 8]
df_9 = df[df['label'] == 9]

n_samples=800 
df_0_balanced = resample(df_0, replace=True, n_samples=n_samples, random_state=42) 
df_1_balanced = resample(df_1, replace=True, n_samples=n_samples, random_state=42) 
df_2_balanced = resample(df_2, replace=True, n_samples=n_samples, random_state=42)
df_3_balanced = resample(df_3, replace=True, n_samples=n_samples, random_state=42)
df_4_balanced = resample(df_4, replace=True, n_samples=n_samples, random_state=42)
df_5_balanced = resample(df_5, replace=True, n_samples=n_samples, random_state=42)
df_6_balanced = resample(df_6, replace=True, n_samples=n_samples, random_state=42)
df_7_balanced = resample(df_7, replace=True, n_samples=n_samples, random_state=42)
df_8_balanced = resample(df_8, replace=True, n_samples=n_samples, random_state=42)
df_9_balanced = resample(df_9, replace=True, n_samples=n_samples, random_state=42)

#Combined back to a single dataframe
tomato_df_balanced = pd.concat([df_0_balanced, df_1_balanced, 
                              df_2_balanced, df_3_balanced, 
                              df_4_balanced, df_5_balanced, df_6_balanced,df_7_balanced
                                ,df_8_balanced,df_9_balanced])

#Check the distribution
print(tomato_df_balanced['label'].value_counts())
# Out:
# 7    800
# 3    800
# 6    800
# 2    800
# 9    800
# 5    800
# 1    800
# 8    800
# 4    800
# 0    800
# Name: label, dtype: int64

# %%
from PIL import Image
SIZE =64

# %%
tomato_df_balanced['image_arr'] = tomato_df_balanced['Image_Path'].map(lambda x: np.asarray(Image.open(x).resize((SIZE,SIZE))))

# %%
print(tomato_df_balanced.iloc[0])
# Out:
# image_name         acbad9e6-d801-48d5-92ee-9fae23fcfb93___UF.GRC_...
# type_of_disease                                       Bacterial_spot
# Image_Path         C:\Users\waseem hasan\plantvillage tomato\plan...
# label                                                              0
# image_arr          [[[104, 104, 102], [104, 104, 102], [105, 105,...
# Name: 1126, dtype: object

# %%
import keras
from keras.utils.np_utils import to_categorical 
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization
from sklearn.model_selection import train_test_split
from scipy import stats

# %%
X = np.asarray(tomato_df_balanced['image_arr'].tolist())
X = X/255. 
Y=tomato_df_balanced['label']  
Y_cat = to_categorical(Y, num_classes=10) 
#Split to training and testing
x_train, x_test, y_train, y_test = train_test_split(X, Y_cat, test_size=0.25, random_state=42)

# %%
num_classes = 10

model = Sequential()
model.add(Conv2D(256, (3, 3), activation="relu", input_shape=(SIZE, SIZE, 3)))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(128, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))

model.add(Conv2D(64, (3, 3),activation='relu'))
#model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))  
model.add(Dropout(0.3))
model.add(Flatten())

model.add(Dense(32))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 62, 62, 256)       7168
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 31, 31, 256)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 31, 31, 256)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 29, 29, 128)       295040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 12, 12, 64)        73792
# ...

# %%
batch_size = 16 
epochs = 20

history = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size = batch_size,
    validation_data=(x_test, y_test),
    verbose=2)

score = model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
model.save("tomato_leaf_classifier.h5")
# Out:
# Epoch 1/20
# 375/375 - 293s - loss: 1.8213 - acc: 0.3472 - val_loss: 1.3800 - val_acc: 0.5205
# Epoch 2/20
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-78-57b1a991d864> in <module>
#       7     batch_size = batch_size,
#       8     validation_data=(x_test, y_test),
# ----> 9     verbose=2)
#      10
#      11 score = model.evaluate(x_test, y_test)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


acc = history.history['acc']
val_acc = history.history['val_acc']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
from keras.models import load_model
loaded_model=load_model("tomato_leaf_classifier.h5")

score = loaded_model.evaluate(x_test, y_test)
print('Test accuracy:', score[1])
# Out:
# 63/63 [==============================] - 21s 219ms/step - loss: 0.2904 - acc: 0.9115
# Test accuracy: 0.9114999771118164

# %%
from sklearn.metrics import confusion_matrix
y_pred = loaded_model.predict(x_test)

y_pred_classes = np.argmax(y_pred, axis = 1) 

y_true = np.argmax(y_test, axis = 1) 

cm = confusion_matrix(y_true, y_pred_classes)

fig, ax = plt.subplots(figsize=(10,10))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)

incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)
plt.bar(np.arange(10), incorr_fraction)
plt.xlabel('True Label')
plt.ylabel('Fraction of incorrect predictions')
# Out:
# Text(58.5, 0.5, 'Fraction of incorrect predictions')
